# %%
import hydra
import pandas as pd
import wandb
import itertools
from datasets import load_dataset
from dotenv import load_dotenv
from langchain.output_parsers import OutputFixingParser
from langchain.schema import StrOutputParser
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.prompts import ChatPromptTemplate
from omegaconf import DictConfig, OmegaConf
from pandas import json_normalize
from tqdm import tqdm

# %%
# from huggingface_hub import notebook_login
# notebook_login()

# %% [markdown]
# **ISSUES**: Error in splitting titles and sections -> REGEX?
#    - Mix between different sections and title
#    - Wrong `section_title value`
#    - `section_content` overlaps information of other sections (e.g., check date columns)
#    - Duplication in `section_title` in one document even same following up position in documents
#
# **NOTES**
# 1. Tested sections: `allergies|history of present illness|past medical history|discharge medications|social history|medications on admission`

# %%
df = load_dataset("bio-datasets/mimoracle", split="train").to_pandas()
df.head()
# Out:
#   subject_id document_id                   chartdate  \
# 0         68        9138  2174-01-03 00:00:00.000000
# 1         68        9138  2174-01-03 00:00:00.000000
# 2         68        9138  2174-01-03 00:00:00.000000
# 3         68        9138  2174-01-03 00:00:00.000000
# 4         68        9138  2174-01-03 00:00:00.000000
#
#                                                 text  \
# 0  Admission Date:  [**2173-12-15**]             ...
# 1  Admission Date:  [**2173-12-15**]             ...
# 2  Admission Date:  [**2173-12-15**]             ...
# 3  Admission Date:  [**2173-12-15**]             ...
# 4  Admission Date:  [**2173-12-15**]             ...
#
#                           section_title  \
# 0                        Admission Date
# 1                         Date of Birth
# 2                             Allergies
# 3                       Chief Complaint
# 4  None\n\n\nHistory of Present Illness
#
#                                      section_content  section_start  \
# 0  [**2173-12-15**]              Discharge Date: ...              0
# 1               [**2132-2-29**]             Sex:   F             80
# 2  Nevirapine / Abacavir / Ampicillin / Tylenol /...            153
# 3                            Productive cough, fever            260
# 4  Ms. [**Known lastname 31473**] is a 41yo F wit...            340
#
#    section_end
# 0           80
# 1          134
# 2          260
# 3          301
# 4         1324

# %%
def _preprocess(text: str) -> str:
    text = text.split('\n')[-1].lower()
    return text

def _resample(df: pd.DataFrame, n_sample:int, n_section:int) -> pd.DataFrame:
    patterns = 'allergies|history of present illness|past medical history|discharge medications|social history|medications on admission'
    df['section_title'] = [_preprocess(x) for x in df['section_title']]
    df = df[df.section_title.str.contains(patterns)]
    df = df.groupby('section_title').filter(lambda x: len(x) > n_sample)
    df = df.groupby('document_id').filter(lambda x: len(x) == n_section)
    return df

# %%
sample_df = _resample(df, 2, 6)
sample_df.head()
# Out:
#    subject_id document_id                   chartdate  \
# 27         68        9139  2174-01-18 00:00:00.000000
# 30         68        9139  2174-01-18 00:00:00.000000
# 31         68        9139  2174-01-18 00:00:00.000000
# 32         68        9139  2174-01-18 00:00:00.000000
# 44         68        9139  2174-01-18 00:00:00.000000
#
#                                                  text  \
# 27  Admission Date:  [**2174-1-4**]              D...
# 30  Admission Date:  [**2174-1-4**]              D...
# 31  Admission Date:  [**2174-1-4**]              D...
# 32  Admission Date:  [**2174-1-4**]              D...
# 44  Admission Date:  [**2174-1-4**]              D...
#
#                  section_title  \
# 27                   allergies
# 30  history of present illness
# 31        past medical history
# 32              social history
# 44    medications on admission
#
#                                       section_content  section_start  \
# 27  Nevirapine / Abacavir / Ampicillin / Tylenol /...            152
# 30  41F with advanced HIV/AIDS (last CD4 5 in [**8...            463
# 31  HIV/AIDS - h/o PCP x 2, MAC, cervical dysplasi...           2124
# 32  Divorced. Lives in apartment with 13 yo daught...           2373
# 44  (unclear which meds pt was taking for the 2 da...           6764
#
#     section_end
# 27          261
# 30         2124
# 31         2373
# 32         2605
# 44         7270

# %%
sample_df.to_csv('mimoracle_sample.csv', index=False)
